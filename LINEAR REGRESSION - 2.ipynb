# %% [markdown]
# ## DAY 5

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression

# %%
gold_data = pd.read_csv('/content/goldprice.csv')

# %%
gold_data.head()
# Out:
#          Open        High         Low       Close   Adj Close    Volume  \
# 0  154.740005  154.949997  151.710007  152.330002  152.330002  21521900
# 1  154.309998  155.369995  153.899994  155.229996  155.229996  18124300
# 2  155.479996  155.860001  154.360001  154.869995  154.869995  12547200
# 3  156.820007  157.429993  156.580002  156.979996  156.979996   9136300
# 4  156.979996  157.529999  156.130005  157.160004  157.160004  11996100
#
#       SP_open     SP_high      SP_low    SP_close  ...    GDX_Low  GDX_Close  \
# 0  123.029999  123.199997  121.989998  122.180000  ...  51.570000  51.680000
# 1  122.230003  122.949997  121.300003  121.589996  ...  52.040001  52.680000
# 2  122.059998  122.320000  120.029999  120.290001  ...  51.029999  51.169998
# 3  122.180000  124.139999  120.370003  123.930000  ...  52.369999  52.990002
# 4  123.930000  124.360001  122.750000  124.169998  ...  52.419998  52.959999
#
#    GDX_Adj Close  GDX_Volume   USO_Open   USO_High    USO_Low  USO_Close  \
# 0      48.973877    20605600  36.900002  36.939999  36.049999  36.130001
# 1      49.921513    16285400  36.180000  36.500000  35.730000  36.270000
# 2      48.490578    15120200  36.389999  36.450001  35.930000  36.200001
# 3      50.215282    11644900  37.299999  37.610001  37.220001  37.560001
# 4      50.186852     8724300  37.669998  38.240002  37.520000  38.110001
#
#    USO_Adj Close  USO_Volume
# 0      36.130001    12616700
# 1      36.270000    12578800
# 2      36.200001     7418200
# 3      37.560001    10041600
# 4      38.110001    10728000
#
# [5 rows x 80 columns]

# %%
gold_data.isnull().sum()
# Out:
# Open             0
# High             0
# Low              0
# Close            0
# Adj Close        0
#                 ..
# USO_High         0
# USO_Low          0
# USO_Close        0
# USO_Adj Close    0
# USO_Volume       0
# Length: 80, dtype: int64

# %%
X = gold_data.drop(['USO_High','USO_Low'],axis=1)
Y = gold_data['USO_Low']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state=101)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = lr.predict(X_test)

# %%
error_score = metrics.r2_score(Y_test, Y_pred)
print("R squared error : ", error_score)
# Out:
# R squared error :  0.9999372266719246

# %%
Y_test = list(Y_test)

# %%
plt.figure(figsize=(25,5))
plt.plot(Y_test, color='blue', label = 'Actual Value')
plt.plot(Y_pred, color='yellow', label='Predicted Value')
plt.title('Actual Price vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GOLD Price')
plt.legend()
plt.show()
